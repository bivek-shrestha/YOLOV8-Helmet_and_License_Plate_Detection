# %% [markdown]
# ## How to Train YOLOv8 Object Detection on a Custom Dataset

# %%
# !nvidia-smi

# %%
# !pip install ultralytics

# %% [markdown]
# ## Install YOLOv8

# %%
from ultralytics import YOLO
import os
from IPython.display import display, Image
from IPython import display
display.clear_output()
# !yolo mode=checks

# %% [markdown]
# ## Train YOLOv8 Model on Custom Dataset

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="y6kxuUIChjOmmcg0CXzl")
project = rf.workspace("rashmi-4dvx3").project("ttv-glg3e")
dataset = project.version(5).download("yolov8")

# %%
# !yolo task=detect mode=train model=yolov8m.pt data={dataset.location}/data.yaml epochs=100 imgsz=640

# %%
# !yolo task=detect mode=val model=/content/runs/detect/train/weights/best.pt data={dataset.location}/data.yaml

# %%
# !yolo task=detect mode=predict model=/content/runs/detect/train/weights/best.pt conf=0.5 source={dataset.location}/test/images save_txt=true save_conf=true
